# %%
import pandas

# %%
import pm4py

# %%
def import_csv(file_path):
    event_log = pandas.read_csv(file_path, sep=',')
    event_log = pm4py.format_dataframe(event_log, case_id='order_id', activity_key='action', timestamp_key='timestamp')
    # start_activities = pm4py.get_start_activities(event_log)
    # end_activities = pm4py.get_end_activities(event_log)
    # print("Start activities: {}\nEnd activities: {}".format(start_activities, end_activities))

    process_tree = pm4py.discover_process_tree_inductive(event_log)
    print(process_tree.parent)
    print(process_tree.children)
    bpmn_model = pm4py.convert_to_bpmn(process_tree)

    pm4py.view_bpmn(bpmn_model)

# %%
if __name__ == "__main__":
    import_csv("./Sample-Event-Log.csv")
# Out:
# /var/folders/w9/vkyp8tms2lldswtxpylnkbkw0000gn/T/ipykernel_94102/915311135.py:3: DeprecatedWarning: format_dataframe is deprecated as of 2.3.0 and will be removed in 3.0.0. the format_dataframe function does not need application anymore.
#   event_log = pm4py.format_dataframe(event_log, case_id='order_id', activity_key='action', timestamp_key='timestamp')
# None
# [Create Passport, Pay, Submit, Process , Check File, X( tau, ->( 'On watchlist', 'Watchlist approved' ) ), Check Photo, Check Documents, Send Passport, Close Case]
